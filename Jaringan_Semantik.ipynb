# %% [markdown]
# <a href="https://colab.research.google.com/github/shellyristy/Manipulasi-Widget/blob/master/Jaringan_Semantik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install py2neo pandas #Menginstall library yang dibutuhkan
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 177 kB 32.2 MB/s
# ...

# %%
#Import Library 
from py2neo import Graph
import pandas as pd

# %%
# from py2neo.matching import RelationshipMatch
# from IPython.core.interactiveshell import no_op
from py2neo import Graph, Node, Relationship

graph = Graph("bolt://44.201.122.202:7687", auth= ("neo4j", "situations-property-flashes"))

node0 = Node("Sastra", name = "Sastra Indonesia")
graph.create(node0)

node1 = Node("Object", name = "Novel")
graph.create(node1)

node2 = Node("Object", name = "Cerpen")
graph.create(node2)

node3 = Node("Object", name = "Puisi")
graph.create(node3)

node4 = Node("Object", name = "Drama")
graph.create(node4)

node5 = Node("Bentuk", name = "Prosa")
graph.create(node5)

node6 = Node("Jenis", name = "Roman a these")
graph.create(node6)

node7 = Node("Jenis", name = "Historical Novel")
graph.create(node7)

node8 = Node("Jenis", name = "Non-Fiksional Novel")
graph.create(node8)

node9 = Node("Contoh", name = "Kusni Kasdut")
graph.create(node9)

node10 = Node("Contoh", name = "Anak Semua Bangsa")
graph.create(node10)

node11 = Node("Contoh", name = "Laskar Pelangi")
graph.create(node11)

node12 = Node("Pegarang", name = "Prakitri T. Simbolon")
graph.create(node12)

node13 = Node("Pengarang", name = "Pramoedya Ananta Toer")
graph.create(node13)

node14 = Node("Pengarang", name = "Andrea Hirata")
graph.create(node14)

node15 = Node("Jenis", name = "Tragedi")
graph.create(node15)

node16 = Node("Jenis", name = "Melodrama")
graph.create(node16)

node17 = Node("Jenis", name = "Komedi")
graph.create(node17)

node18 = Node("Contoh", name = "Kapal-Kapal")
graph.create(node18)

node19 = Node("Contoh", name = "Dag Dig Dug")
graph.create(node19)

node20 = Node("Contoh", name = "Pagi Bening")
graph.create(node20)

node21 = Node("Pengarang", name = "Arifin.C")
graph.create(node21)

node22 = Node("Pengarang", name = "Putu Wijaya")
graph.create(node22)

node23 = Node("Pengarang", name = "Serafin dan Jeraquin")
graph.create(node23)

node24 = Node("Elemen", name = "Wawacang")
graph.create(node24)

node25 = Node("Elemen", name = "Tokoh")
graph.create(node25)

node26 = Node("Elemen", name = "Kamatung")
graph.create(node26)

node27 = Node("Unsur Intrinsik", name = "Sudut Pandang")
graph.create(node27)

node28 = Node("Unsur Intrinsik", name = "Amanat")
graph.create(node28)

node29 = Node("Unsur Intrinsik", name = "Latar")
graph.create(node29)

node30 = Node("Unsur Intrinsik", name = "Alur")
graph.create(node30)

node31 = Node("Unsur Intrinsik", name = "Tokoh")
graph.create(node31)

node32 = Node("Jenis", name = "Puisi Lama")
graph.create(node32)

node33 = Node("Jenis", name = "Pantun")
graph.create(node33)

node34 = Node("Jenis", name = "Gurindam")
graph.create(node34)

node35 = Node("Jenis", name = "Syair")
graph.create(node35)

node36 = Node("Contoh", name = "Aku")
graph.create(node36)

node37 = Node("Contoh", name = "Pantun Nasehat")
graph.create(node37)

node38 = Node("Contoh", name = "Raja Ali Haji")
graph.create(node38)

node39 = Node("Contoh", name = "Senja di Pelabuhan Sore")
graph.create(node39)

node40 = Node("Pengarang", name = "Chairil Anwar")
graph.create(node40)

node41 = Node("Pengarang", name = "Asriadi")
graph.create(node41)

node42 = Node("Pengarang", name = "Raja Ali Haji")
graph.create(node42)

node43 = Node("Pembacaan", name = "Rima")
graph.create(node43)

node44 = Node("Pembacaan", name = "Diksi")
graph.create(node44)

node45 = Node("Pembacaan", name = "Imaji")
graph.create(node45)

node46 = Node("Pembacaan", name = "Tipografi")
graph.create(node46)

node47 = Node("Pembacaan", name = "Gaya Bahasa")
graph.create(node47)

node48 = Node("Contoh", name = "Ranggalawe Gugur")
graph.create(node48)

node49 = Node("Unsur Intrinsik", name = "Tema")
graph.create(node49)

node50 = Node("Unsur Intrinsik", name = "Latar")
graph.create(node50)

node51 = Node("Unsur Intrinsik", name = "Alur")
graph.create(node51)

node52 = Node("Alur", name = "Maju")
graph.create(node52)

node53 = Node("Alur", name = "Mundur")
graph.create(node53)

node54 = Node("Alur", name = "Campuran")
graph.create(node54)


# pusat
graph.create(Relationship(node0, "jenis", node1))
graph.create(Relationship(node0, "jenis", node2))
graph.create(Relationship(node0, "jenis", node3))
graph.create(Relationship(node0, "jenis", node4))
# bentuk
graph.create(Relationship(node1, "Bentuk", node5))
graph.create(Relationship(node2, "Bentuk", node5))
# jenis novel
graph.create(Relationship(node1, "Jenis", node6))
graph.create(Relationship(node1, "Jenis", node7))
graph.create(Relationship(node1, "Jenis", node8))
# contoh novel
graph.create(Relationship(node6, "Contoh", node9))
graph.create(Relationship(node7, "Contoh", node10))
graph.create(Relationship(node8, "Contoh", node11))
# Pengarang Novel
graph.create(Relationship(node9, "Pengarang", node12))
graph.create(Relationship(node10, "Pengarang", node13))
graph.create(Relationship(node11, "Pengarang", node14))
# Unsur Intrinsik Novel
graph.create(Relationship(node1, "Unsur Intrinsik", node27))
graph.create(Relationship(node1, "Unsur Intrinsik", node28))
graph.create(Relationship(node1, "Unsur Intrinsik", node29))
graph.create(Relationship(node1, "Unsur Intrinsik", node30))
graph.create(Relationship(node1, "Unsur Intrinsik", node31))
# Jenis Drama
graph.create(Relationship(node4, "Jenis", node15))
graph.create(Relationship(node4, "Jenis", node16))
graph.create(Relationship(node4, "Jenis", node17))
# Contoh Drama
graph.create(Relationship(node15, "Contoh", node18))
graph.create(Relationship(node16, "Contoh", node19))
graph.create(Relationship(node17, "Contoh", node20))
# Pengarang Drama
graph.create(Relationship(node18, "Pengarang", node21))
graph.create(Relationship(node19, "Pengarang", node22))
graph.create(Relationship(node20, "Pengarang", node23))
# Elemen Drama
graph.create(Relationship(node4, "Elemen", node24))
graph.create(Relationship(node4, "Elemen", node25))
graph.create(Relationship(node4, "Elemen", node26))
# Jenis Puisi
graph.create(Relationship(node3, "Jenis", node32))
graph.create(Relationship(node3, "Jenis", node33))
graph.create(Relationship(node3, "Jenis", node34))
graph.create(Relationship(node3, "Jenis", node35))
# Contoh Puisi
graph.create(Relationship(node32, "Contoh", node36))
graph.create(Relationship(node33, "Contoh", node37))
graph.create(Relationship(node34, "Contoh", node38))
graph.create(Relationship(node35, "Contoh", node39))
# Pengarang Puisi
graph.create(Relationship(node36, "Pengarang", node40))
graph.create(Relationship(node37, "Pengarang", node41))
graph.create(Relationship(node38, "Pengarang", node42))
graph.create(Relationship(node39, "Pengarang", node40))
# Pembacaan Puisi
graph.create(Relationship(node3, "Pembacaan", node43))
graph.create(Relationship(node3, "Pembacaan", node44))
graph.create(Relationship(node3, "Pembacaan", node45))
graph.create(Relationship(node3, "Pembacaan", node46))
graph.create(Relationship(node3, "Pembacaan", node47))
# Unsur Cerpen
graph.create(Relationship(node2, "Unsur Intrinsik", node49))
graph.create(Relationship(node2, "Unsur Intrinsik", node50))
graph.create(Relationship(node2, "Unsur Intrinsik", node51))
# Alur Cerpen
graph.create(Relationship(node51, "Alur", node52))
graph.create(Relationship(node51, "Alur", node53))
graph.create(Relationship(node51, "Alur", node54))
# Contoh Cerpen
graph.create(Relationship(node2, "Contoh", node48))
graph.create(Relationship(node48, "Pengarang", node40))
